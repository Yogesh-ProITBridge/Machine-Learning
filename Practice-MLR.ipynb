# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# #### 1. Import Necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# #### 2. Load the dataset

# %%
petrol_consp = pd.read_csv('petrol_consumption.csv')

# %%
petrol_consp
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %% [markdown]
# #### 3. Getting know about dataset

# %%
petrol_consp.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
petrol_consp.tail()
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 43         7.0            3745            2611                         0.508
# 44         6.0            5215            2302                         0.672
# 45         9.0            4476            3942                         0.571
# 46         7.0            4296            4083                         0.623
# 47         7.0            5002            9794                         0.593
#
#     Petrol_Consumption
# 43                 591
# 44                 782
# 45                 510
# 46                 610
# 47                 524

# %%
petrol_consp.shape
# Out:
# (48, 5)

# %%
petrol_consp.dtypes
# Out:
# Petrol_tax                      float64
# Average_income                    int64
# Paved_Highways                    int64
# Population_Driver_licence(%)    float64
# Petrol_Consumption                int64
# dtype: object

# %%
petrol_consp.isna().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %% [markdown]
# ### 4. Data Preparation

# %% [markdown]
# There is no need for preparation because it good to Model building

# %% [markdown]
# ### 5. Assumption Test

# %% [markdown]
# ### Assumption 1: Normality Check
# We should check for thr data distribution - Histogram

# %%
sns.histplot(data=petrol_consp['Petrol_tax'],kde=True)
plt.title('Normality check on Petrol_tax')
plt.show()

# %%
sns.histplot(data=petrol_consp['Average_income'],kde=True)
plt.title('Normality check on Average_income')
plt.show()

# %%
sns.histplot(data=petrol_consp['Paved_Highways'],kde=True)
plt.title('Normality check on Paved_Highways')
plt.show()

# %%
sns.histplot(data=petrol_consp['Population_Driver_licence(%)'],kde=True)
plt.title('Normality check on Population_Driver_licence(%)')
plt.show()

# %% [markdown]
# **- Normality check Failed**

# %% [markdown]
# ### Assumption 2: Linearity Check
# -  The data has to be linear in nature

# %%
sns.lmplot(data=petrol_consp, x='Petrol_tax',y='Petrol_Consumption')
plt.title("Petrol_tax vs Petrol_Consumption")
plt.show()

# %%
sns.lmplot(data=petrol_consp, x='Average_income',y='Petrol_Consumption')
plt.title("Average_income vs Petrol_Consumption")
plt.show()

# %%
sns.lmplot(data=petrol_consp, x='Paved_Highways',y='Petrol_Consumption')
plt.title("Paved_Highways vs Petrol_Consumption")
plt.show()

# %%
sns.lmplot(data=petrol_consp, x='Population_Driver_licence(%)',y='Petrol_Consumption')
plt.title("Population_Driver_licence(%) vs Petrol_Consumption")
plt.show()

# %% [markdown]
# **- Linearity check Failed**

# %% [markdown]
# ### Asummptions 3 : No Multicolinearity
# -  Understand the strength of the linear association or relationship between the features.Co-relation matrix

# %%
petrol_consp_corr=petrol_consp.corr()

# %%
sns.heatmap(data=petrol_consp_corr,annot=True)
plt.show()

# %% [markdown]
# **- Multicolinearity check is failed**

# %% [markdown]
# ### Assumption 4: No Autoregression
# - There is no time\date in the features.So, its not influenced by time

# %% [markdown]
# **Assumptions 5 and 6 - Homoscadacity and Zero residual mean will be done after at ethe end.**

# %% [markdown]
# ### 4. Data preparation
# - No needed as everything is fine with our data

# %% [markdown]
# ### 5. Model Building

# %%
x = petrol_consp.drop(['Petrol_Consumption'],axis=1)
y = petrol_consp['Petrol_Consumption']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=23)

# %%
x_train
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 43        7.00            3745            2611                         0.508
# 10        8.00            4391            5939                         0.530
# 29        9.00            3601            4650                         0.493
# 3         7.50            4870            2351                         0.529
# 22        9.00            4897            2449                         0.511
# 36        5.00            4045           17782                         0.566
# 28        8.00            4188            5975                         0.563
# 33        7.50            3357            4121                         0.547
# 24        8.50            4574            2619                         0.551
# 23        9.00            4258            4686                         0.517
# 4         8.00            4399             431                         0.544
# ...

# %%
x_test
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 14         7.0            4332            8159                         0.608
# 18         7.0            4716            5915                         0.724
# 17         7.0            3718            4725                         0.540
# 30         7.0            3640            6905                         0.518
# 13         7.0            4207            6580                         0.545
# 42         7.0            4300            3635                         0.603
# 20         7.0            4593            7834                         0.663
# 8          8.0            4447            8577                         0.529
# 34         8.0            3528            3495                         0.487
# 46         7.0            4296            4083                         0.623

# %%
y_train
# Out:
# 43    591
# 10    580
# 29    534
# 3     414
# 22    464
# 36    640
# 28    574
# 33    628
# 24    460
# 23    547
# 4     410
# 37    704
# 7     467
# 1     524
# 47    524
# 15    635
# 44    782
# 16    603
# 32    577
# 35    644
# 0     541
# 5     457
# 21    540
# 11    471
# 2     561
# 41    699
# 6     344
# 25    566
# 26    577
# 39    968
# 27    631
# 12    525
# 31    554
# 45    510
# 9     498
# 40    587
# 38    648
# 19    640
# Name: Petrol_Consumption, dtype: int64

# %%
y_test
# Out:
# 14    566
# 18    865
# 17    714
# 30    571
# 13    508
# 42    632
# 20    649
# 8     464
# 34    487
# 46    610
# Name: Petrol_Consumption, dtype: int64

# %% [markdown]
# ### 6. Model Training

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
linear_model=LinearRegression()

# %%
linear_model
# Out:
# LinearRegression()

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model.intercept_
# Out:
# 380.20849485543056

# %%
linear_model.coef_
# Out:
# array([-3.43753253e+01, -6.41232263e-02, -1.78621451e-03,  1.30461600e+03])

# %% [markdown]
# ### 7. Model Testing

# %%
y_trained=linear_model.predict(x_test)

# %%
y_trained
# Out:
# array([640.43220459, 771.15260697, 597.22383819, 569.62995024,
#        569.07723263, 644.04190227, 696.03044221, 494.87140662,
#        508.08432173, 669.59049106])

# %% [markdown]
# ### 8.Model Evalution

# %% [markdown]
# ### Assumption 5: Homoscadascity
