# %% [markdown]
# ## 1. Import Necessary libraries

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Load the dataset

# %%
retail_data = pd.read_excel('Online Retail.xlsx')
retail_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ## 3. Data Understaing

# %%
retail_data.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
retail_data.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail_data['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
retail_data['Country'].nunique()
# Out:
# 38

# %%
retail_data['Country'].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %% [markdown]
# ## 4. Data Preparation

# %%
france_retail_data = retail_data[retail_data['Country']=='France']

# %%
france_retail_data
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# ...

# %%
france_data_pivoted=pd.pivot_table(data= france_retail_data,values='UnitPrice',index='InvoiceNo',columns='Description').fillna(0)

# %%
france_data_one_hot= france_data_pivoted.applymap(lambda x: 1 if x>0 else 0)
france_data_one_hot
# Out:
# C:\Users\venka\AppData\Local\Temp\ipykernel_9364\792759378.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   france_data_one_hot= france_data_pivoted.applymap(lambda x: 1 if x>0 else 0)
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                    0                   0
# 536852                                    0                   0
# 536974                                    0                   0
# 537065                                    0                   0
# 537463                                    0                   0
# ...                                     ...                 ...
# C579532                                   0                   0
# C579562                                   0                   0
# C580161                                   0                   0
# C580263                                   0                   0
# ...

# %% [markdown]
# ## 5. Data Mining

# %%
# !pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 262.6 kB/s eta 0:00:06
#     --------------------------------------- 0.0/1.4 MB 262.6 kB/s eta 0:00:06
#     --------------------------------------- 0.0/1.4 MB 262.6 kB/s eta 0:00:06
#    - -------------------------------------- 0.0/1.4 MB 140.3 kB/s eta 0:00:11
#    - -------------------------------------- 0.0/1.4 MB 140.3 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/1.4 MB 163.6 kB/s eta 0:00:09
#    - -------------------------------------- 0.1/1.4 MB 163.6 kB/s eta 0:00:09
#    - -------------------------------------- 0.1/1.4 MB 151.3 kB/s eta 0:00:10
#    - -------------------------------------- 0.1/1.4 MB 151.3 kB/s eta 0:00:10
#    - -------------------------------------- 0.1/1.4 MB 151.3 kB/s eta 0:00:10
# ...

# %%
from mlxtend.frequent_patterns import apriori,association_rules
#Apriori=frequent itemssets
#Association rules - To find the best associated product

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
france_apriori=apriori(df=france_data_one_hot,
    min_support=0.02,
    use_colnames=True,)
france_apriori
# Out:
#        support                                           itemsets
# 0     0.034707                          ( SPACEBOY BABY GIFT SET)
# 1     0.026030                           (10 COLOUR SPACEBOY PEN)
# 2     0.021692               (12 PENCILS TALL TUBE RED RETROSPOT)
# 3     0.030369               (3 PIECE SPACEBOY COOKIE CUTTER SET)
# 4     0.041215                    (36 PENCILS TUBE RED RETROSPOT)
# ...        ...                                                ...
# 1311  0.023861  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 1312  0.021692  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 1313  0.023861  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 1314  0.023861  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 1315  0.021692  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
#
# [1316 rows x 2 columns]

# %%
best_associated=association_rules(df=france_apriori,
                                 metric='support',
                                 min_threshold=0.02)

# %%
best_associated
# Out:
#                                antecedents  \
# 0                 (10 COLOUR SPACEBOY PEN)
# 1                                (POSTAGE)
# 2     (3 PIECE SPACEBOY COOKIE CUTTER SET)
# 3                                (POSTAGE)
# 4          (36 PENCILS TUBE RED RETROSPOT)
# ...                                    ...
# 6391        (PACK OF 6 SKULL PAPER PLATES)
# 6392          (PACK OF 6 SKULL PAPER CUPS)
# 6393      (PACK OF 20 SKULL PAPER NAPKINS)
# 6394         (SET/6 RED SPOTTY PAPER CUPS)
# 6395                             (POSTAGE)
#
#                                             consequents  antecedent support  \
# 0                                             (POSTAGE)            0.026030
# 1                              (10 COLOUR SPACEBOY PEN)            0.674620
# 2                                             (POSTAGE)            0.030369
# 3                  (3 PIECE SPACEBOY COOKIE CUTTER SET)            0.674620
# ...

# %%
best_associated.to_csv()

# %%
Germany_retail_data = retail_data[retail_data['Country']=='Germany']

# %%
Germany_retail_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 1109      536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110      536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111      536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112      536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113      536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...          ...       ...                                  ...       ...
# 541801    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 541802    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 541803    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 541804    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 541805    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#                InvoiceDate  UnitPrice  CustomerID  Country
# ...

# %%
Germany_data_pivoted=pd.pivot_table(data= Germany_retail_data,values='UnitPrice',index='InvoiceNo',columns='Description').fillna(0)
Germany_data_one_hot= Germany_data_pivoted.applymap(lambda x: 1 if x>0 else 0)
Germany_data_one_hot
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                    0                   0
# 536840                                    0                   0
# 536861                                    0                   0
# 536967                                    0                   0
# 536983                                    0                   0
# ...                                     ...                 ...
# C580313                                   0                   0
# C580714                                   0                   0
# C580740                                   0                   0
# C580989                                   0                   0
# C581409                                   0                   0
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                                  0                         0
# ...
